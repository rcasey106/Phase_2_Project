# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Reading in the data

# %%
df = pd.read_csv(r"C:\Users\User1\Desktop\dsc-phase-2-project-v2-3-main\dsc-phase-2-project-v2-3-main\data\kc_house_data.csv")
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# ...

# %% [markdown]
# ### Filtering out houses with bedrooms >11

# %%
df1 = df[df['bedrooms']<33]

# %%
df['bedrooms'].max()
# Out:
# 33

# %%
df1['bedrooms'].max()
# Out:
# 11

# %% [markdown]
# ### Checking the column names

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ### Looking at the values of the categorical variables

# %%
variable_names = df.columns

# %% [markdown]
# ### Looping through variables to look at values

# %%
for i in variable_names:
    print(df[i].value_counts(dropna = False))
# Out:
# 795000620     3
# 1825069031    2
# 2019200220    2
# 7129304540    2
# 1781500435    2
#              ..
# 7812801125    1
# 4364700875    1
# 3021059276    1
# 880000205     1
# 1777500160    1
# Name: id, Length: 21420, dtype: int64
# 6/23/2014    142
# 6/26/2014    131
# 6/25/2014    131
# 7/8/2014     127
# 4/27/2015    126
#             ...
# 1/31/2015      1
# 5/15/2015      1
# 5/27/2015      1
# 3/8/2015       1
# 2/15/2015      1
# Name: date, Length: 372, dtype: int64
# 350000.0    172
# 450000.0    172
# 550000.0    159
# 500000.0    152
# 425000.0    150
#            ...
# 870515.0      1
# 336950.0      1
# 386100.0      1
# 176250.0      1
# 884744.0      1
# Name: price, Length: 3622, dtype: int64
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# ...

# %% [markdown]
# ### Counting the nulls for each variable

# %%
for i in variable_names:
    print(i)
    print(df[i].isna().sum())
    print('________')
# Out:
# id
# 0
# ________
# date
# 0
# ________
# price
# 0
# ________
# bedrooms
# 0
# ________
# bathrooms
# 0
# ________
# sqft_living
# 0
# ________
# sqft_lot
# 0
# ________
# floors
# 0
# ________
# waterfront
# 2376
# ________
# view
# 63
# ________
# condition
# 0
# ________
# grade
# 0
# ________
# sqft_above
# 0
# ________
# sqft_basement
# 0
# ________
# yr_built
# 0
# ________
# yr_renovated
# 3842
# ________
# zipcode
# 0
# ________
# lat
# 0
# ________
# long
# 0
# ________
# sqft_living15
# 0
# ________
# sqft_lot15
# 0
# ________

# %% [markdown]
# ### Creating a category for the nulls

# %%
df['waterfront'].value_counts(dropna=False)
# Out:
# NO     19075
# NaN     2376
# YES      146
# Name: waterfront, dtype: int64

# %%
df['Waterfront'] = df['waterfront'].fillna('MISSING')

# %%
df['Waterfront'].value_counts()
# Out:
# NO         19075
# MISSING     2376
# YES          146
# Name: Waterfront, dtype: int64

# %% [markdown]
# ### Creating dummy variable for missing year

# %%
df['yr_renovated'].value_counts(dropna = False) # assume that 0.0 means it was not renovated
# Out:
# 0.0       17011
# NaN        3842
# 2014.0       73
# 2003.0       31
# 2013.0       31
#           ...
# 1944.0        1
# 1948.0        1
# 1976.0        1
# 1934.0        1
# 1953.0        1
# Name: yr_renovated, Length: 71, dtype: int64

# %%
df['yr_renovated']=df['yr_renovated'].fillna(0)
df['yr_renovated'].value_counts()
# Out:
# 0.0       20853
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df.loc[df['yr_renovated']==0, 'is_renovated'] = 0
df.loc[df['is_renovated'].isna(), 'is_renovated'] = 1

# %%
df['is_renovated'].value_counts()
# Out:
# 0.0    20853
# 1.0      744
# Name: is_renovated, dtype: int64

# %% [markdown]
# ### Getting value counts for the view column

# %%
df['view'].value_counts(dropna = False)
# Out:
# NONE         19422
# AVERAGE        957
# GOOD           508
# FAIR           330
# EXCELLENT      317
# NaN             63
# Name: view, dtype: int64

# %%
df['View'] = df['view'].fillna('MISSING')

# %%
df['View'].value_counts()
# Out:
# NONE         19422
# AVERAGE        957
# GOOD           508
# FAIR           330
# EXCELLENT      317
# MISSING         63
# Name: View, dtype: int64

# %%
df[['sqft_living', 'sqft_lot', 'sqft_above']].describe()
# Out:
#         sqft_living      sqft_lot    sqft_above
# count  21597.000000  2.159700e+04  21597.000000
# mean    2080.321850  1.509941e+04   1788.596842
# std      918.106125  4.141264e+04    827.759761
# min      370.000000  5.200000e+02    370.000000
# 25%     1430.000000  5.040000e+03   1190.000000
# 50%     1910.000000  7.618000e+03   1560.000000
# 75%     2550.000000  1.068500e+04   2210.000000
# max    13540.000000  1.651359e+06   9410.000000

# %%
df['sqft_basement'].value_counts() #change ? to something
#can subtract living from above
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 946.0         1
# 1008.0        1
# 3260.0        1
# 602.0         1
# 1913.0        1
# Name: sqft_basement, Length: 304, dtype: int64

# %%
df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'yr_built', 'yr_renovated']].describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   5.402966e+05      3.373200      2.115826   2080.321850  1.509941e+04
# std    3.673681e+05      0.926299      0.768984    918.106125  4.141264e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068500e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above      yr_built  yr_renovated
# count  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096   1788.596842   1970.999676     68.758207
# std        0.539683    827.759761     29.375234    364.037499
# ...

# %%
price_zipcode = df1.groupby('zipcode')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_zipcode
# Out:
#     zipcode  count          mean           std       min        25%  \
# 0     98039   50.0  2.161300e+06  1.166904e+06  787500.0  1402500.0
# 1     98004  317.0  1.356524e+06  7.460941e+05  425000.0   845000.0
# 2     98040  282.0  1.194874e+06  6.077676e+05  500000.0   822000.0
# 3     98112  269.0  1.096239e+06  5.942232e+05  169317.0   680000.0
# 4     98102  104.0  8.996077e+05  7.903814e+05  330000.0   571875.0
# ..      ...    ...           ...           ...       ...        ...
# 65    98148   57.0  2.849086e+05  8.961694e+04  105500.0   240000.0
# 66    98001  361.0  2.811949e+05  9.883743e+04  100000.0   215000.0
# 67    98032  125.0  2.512962e+05  6.470543e+04   85000.0   221700.0
# 68    98168  269.0  2.403284e+05  6.998482e+04   78000.0   199950.0
# 69    98002  199.0  2.342840e+05  5.204145e+04   95000.0   199975.0
#
#           50%        75%        max
# 0   1895000.0  2560000.0  6890000.0
# 1   1150000.0  1690000.0  7060000.0
# 2    993750.0  1387500.0  5300000.0
# ...

# %%
price_bedrooms = df1.groupby('bedrooms')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_bedrooms
# Out:
#     bedrooms   count          mean            std       min        25%  \
# 0          8    13.0  1.105077e+06  897495.725295  340000.0  490000.00
# 1          7    38.0  9.514478e+05  740350.184560  280000.0  539250.00
# 2          9     6.0  8.939998e+05  381533.900984  450000.0  624999.25
# 3          6   272.0  8.258535e+05  799610.343019  175000.0  435000.00
# 4         10     3.0  8.200000e+05  285832.118559  650000.0  655000.00
# 5          5  1601.0  7.868741e+05  596536.599057  133000.0  438000.00
# 6          4  6882.0  6.355647e+05  388901.182117  100000.0  376962.50
# 7         11     1.0  5.200000e+05            NaN  520000.0  520000.00
# 8          3  9824.0  4.662766e+05  262620.685862   82000.0  295487.50
# 9          2  2760.0  4.013877e+05  198128.920756   78000.0  269837.50
# 10         1   196.0  3.182395e+05  148589.635501   80000.0  223000.00
#
#          50%        75%        max
# 0   700000.0  1650000.0  3300000.0
# 1   728580.0   946500.0  3200000.0
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['zipcode'],df['price'], 'o', color='black');
#BOX PLOTS PREFERRED FOR CATEGORICAL, SEABORN

# %%
plt.bar(price_bedrooms['bedrooms'], price_bedrooms['mean'], align='center', alpha=0.5)
#plt.xticks(rotation = 70)#rotation
plt.title('Mean Price per Number of Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
price_bathrooms = df1.groupby('bathrooms')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_bathrooms
# Out:
#     bathrooms   count          mean           std        min        25%  \
# 0        7.75     1.0  6.890000e+06           NaN  6890000.0  6890000.0
# 1        8.00     2.0  4.990000e+06  3.832519e+06  2280000.0  3635000.0
# 2        6.25     2.0  3.095000e+06  2.899138e+05  2890000.0  2992500.0
# 3        6.00     6.0  2.948333e+06  1.706475e+06   900000.0  1655000.0
# 4        6.75     2.0  2.735000e+06  2.736503e+06   800000.0  1767500.0
# 5        5.50    10.0  2.522500e+06  1.254634e+06   925000.0  1525000.0
# 6        5.75     4.0  2.492500e+06  2.153778e+06   540000.0  1575000.0
# 7        4.75    23.0  2.022300e+06  8.672724e+05   480000.0  1360000.0
# 8        5.25    13.0  1.817962e+06  1.241665e+06   300000.0  1150000.0
# 9        6.50     2.0  1.710000e+06  7.495332e+05  1180000.0  1445000.0
# 10       5.00    21.0  1.674167e+06  1.248295e+06   343000.0   740000.0
# 11       4.25    79.0  1.526653e+06  7.616379e+05   490000.0   927500.0
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.bar(price_bathrooms['bathrooms'], price_bathrooms['mean'], width = 0.25)
#plt.xticks(rotation = 70)
plt.title('Mean Price per Number of Bathrooms')
plt.ylabel('Price')
plt.show()
#overlap

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['sqft_living'],df['price'], 'o', color='black');

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['sqft_lot'],df['price'], 'o', color='black');

# %%
price_floors = df1.groupby('floors')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_floors
# Out:
#    floors    count          mean           std       min       25%       50%  \
# 0     2.5    161.0  1.061021e+06  8.588360e+05  255000.0  550000.0  799200.0
# 1     3.5      7.0  9.102143e+05  1.054669e+06  435000.0  502000.0  525000.0
# 2     2.0   8235.0  6.491856e+05  4.342366e+05   90000.0  379000.0  543000.0
# 3     3.0    611.0  5.834339e+05  3.387434e+05  205000.0  385000.0  491000.0
# 4     1.5   1910.0  5.590449e+05  3.037221e+05   92000.0  355000.0  524475.0
# 5     1.0  10672.0  4.423399e+05  2.641739e+05   78000.0  275475.0  390000.0
#
#          75%        max
# 0  1300000.0  7700000.0
# 1   553750.0  3300000.0
# 2   772500.0  7060000.0
# 3   633250.0  3100000.0
# 4   687875.0  3650000.0
# 5   530000.0  4670000.0

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.bar(price_floors['floors'], price_floors['mean'], align='center', alpha=0.5, width = 0.4)
#plt.xticks(rotation = 70)
plt.title('Mean Price per Number of Floors')
plt.ylabel('Price')
plt.show()

# %%
price_waterfront = df1.groupby('waterfront')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_waterfront
# Out:
#   waterfront    count          mean           std       min       25%  \
# 0        YES    146.0  1.717215e+06  1.145385e+06  285000.0  827500.0
# 1         NO  19074.0  5.326364e+05  3.449673e+05   78000.0  320000.0
#
#          50%        75%        max
# 0  1510000.0  2282500.0  7060000.0
# 1   450000.0   638500.0  7700000.0

# %%
df['waterfront'].value_counts()
# Out:
# NO     19075
# YES      146
# Name: waterfront, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.hist(df[df['waterfront'] == 'YES']['price'], alpha=0.5, label="data1")
plt.hist(df[df['waterfront'] == 'NO']['price'], alpha=0.5, label="data2")
plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='upper right')
plt.savefig("overlapping_histograms_with_matplotlib_Python_2.png")

# %%
plt.figure(figsize=(8,6))
plt.hist(df[df['waterfront'] == 'YES']['price'], alpha=0.5, label="data1")

plt.xlabel("Data", size=14)
plt.ylabel("Count", size=14)
plt.title("Multiple Histograms with Matplotlib")
plt.legend(loc='upper right')
plt.savefig("overlapping_histograms_with_matplotlib_Python_2.png")

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['sqft_above'],df['price'], 'o', color='black');

# %%
price_yr_built = df.groupby('yr_built')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_yr_built
# Out:
#      yr_built  count           mean            std       min        25%  \
# 0        1933   30.0  772483.333333  755694.935751  156000.0  248500.00
# 1        2015   38.0  759970.947368  421467.055816  230000.0  500000.00
# 2        1905   74.0  753443.932432  464623.225982   90000.0  438750.00
# 3        2001  305.0  741340.042623  669787.922238  213400.0  431000.00
# 4        1909   94.0  696448.989362  457988.175033  185900.0  448750.00
# ..        ...    ...            ...            ...       ...        ...
# 111      1961  224.0  432230.928571  239516.285810  125000.0  269623.25
# 112      1969  280.0  425526.450000  334104.306272   89000.0  230000.00
# 113      1942  223.0  379312.919283  229408.727522   78000.0  250000.00
# 114      1944  140.0  356322.078571  159671.781230  100000.0  229212.50
# 115      1943  170.0  333347.000000  170781.516254   81000.0  226662.50
#
#           50%         75%        max
# 0    402500.0  1149750.00  3200000.0
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['yr_built'],df['price'], 'o', color='black');

# %%
price_yr_renovated = df.groupby('yr_renovated')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_yr_renovated
# Out:
#     yr_renovated  count          mean           std       min       25%  \
# 0         1987.0   14.0  1.387571e+06  2.008522e+06  212000.0  505500.0
# 1         2002.0   17.0  1.267526e+06  9.432781e+05  397950.0  664000.0
# 2         2001.0   15.0  1.238720e+06  1.671964e+06  215000.0  583000.0
# 3         2010.0   15.0  1.051937e+06  7.470332e+05  297950.0  640000.0
# 4         1999.0   15.0  1.022100e+06  5.612989e+05  350000.0  693750.0
# ..           ...    ...           ...           ...       ...       ...
# 65        1951.0    1.0  2.760000e+05           NaN  276000.0  276000.0
# 66        1967.0    2.0  2.686000e+05  3.026417e+04  247200.0  257900.0
# 67        1960.0    3.0  2.529000e+05  1.249869e+05  160000.0  181850.0
# 68        1953.0    1.0  2.475000e+05           NaN  247500.0  247500.0
# 69        1950.0    1.0  1.529000e+05           NaN  152900.0  152900.0
#
#          50%        75%        max
# 0   674000.0   842875.0  7700000.0
# ...

# %%
df2 = df1[df1['yr_renovated']>0]

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df2['yr_renovated'],df2['price'], 'o', color='black');

# %%
price_lat = df.groupby('lat')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_lat
# Out:
#           lat  count          mean           std        min        25%  \
# 0     47.6165    2.0  2.795000e+06  1.195010e+06  1950000.0  2372500.0
# 1     47.6305    5.0  2.417990e+06  2.668729e+06   549950.0   820000.0
# 2     47.6298    6.0  2.093450e+06  2.777277e+06   635700.0   646250.0
# 3     47.6263    6.0  1.946667e+06  1.004384e+06   610000.0  1412500.0
# 4     47.6500    6.0  1.914833e+06  2.545560e+06   615000.0   674750.0
# ...       ...    ...           ...           ...        ...        ...
# 5028  47.4191    1.0  1.200000e+05           NaN   120000.0   120000.0
# 5029  47.2841    1.0  1.150000e+05           NaN   115000.0   115000.0
# 5030  47.4523    1.0  1.100000e+05           NaN   110000.0   110000.0
# 5031  47.2997    1.0  1.000000e+05           NaN   100000.0   100000.0
# 5032  47.2777    1.0  1.000000e+05           NaN   100000.0   100000.0
#
#             50%        75%        max
# 0     2795000.0  3217500.0  3640000.0
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['lat'],df['price'], 'o', color='black');

# %%
price_long = df.groupby('long')['price'].describe().sort_values(by = 'mean', ascending = False).reset_index()
price_long
# Out:
#         long  count          mean            std        min         25%  \
# 0   -122.448    1.0  1.380000e+06            NaN  1380000.0  1380000.00
# 1   -122.451    1.0  1.350000e+06            NaN  1350000.0  1350000.00
# 2   -122.416    4.0  1.211750e+06  514617.252593   729000.0   855750.00
# 3   -121.952    5.0  1.140000e+06  508736.179173   475000.0   865000.00
# 4   -122.406   18.0  1.128067e+06  702651.813558   290000.0   721008.25
# ..       ...    ...           ...            ...        ...         ...
# 746 -121.325    1.0  1.600000e+05            NaN   160000.0   160000.00
# 747 -121.315    2.0  1.585000e+05   12020.815280   150000.0   154250.00
# 748 -121.364    2.0  1.575000e+05    3535.533906   155000.0   156250.00
# 749 -121.316    1.0  1.550000e+05            NaN   155000.0   155000.00
# 750 -121.359    1.0  1.340000e+05            NaN   134000.0   134000.00
#
#            50%        75%        max
# 0    1380000.0  1380000.0  1380000.0
# ...

# %%
fig, ax = plt.subplots(figsize = (12,6))
plt.plot(df['long'],df['price'], 'o', color='black');

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from patsy import dmatrices

# %%
dummy1 = pd.get_dummies(df1, columns = ['waterfront'])
dummy1
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  view  condition  ... zipcode      lat     long  \
# ...

# %%
dummy2 = dummy1.dropna()

# %%
X = dummy2.loc[:,['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors',
       'sqft_above']]
y = dummy2['price']
X_constant = sm.add_constant(X)
#X=X.reshape(-1,1)

# %%
X1 = dummy2.loc[:,['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors',
       'sqft_above', 'yr_built', 'yr_renovated','waterfront_YES']]
y1 = dummy2['price']
X1_constant = sm.add_constant(X1)
#X=X.reshape(-1,1)

# %%
X2 = dummy2.loc[:,['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors',
        'yr_built', 'yr_renovated','waterfront_YES']].values
y2 = dummy2['price']
X2_constant = sm.add_constant(X2)
#X=X.reshape(-1,1)

# %%
X3 = dummy2.loc[:,['bedrooms', 'sqft_living',
       'sqft_lot', 'floors',
        'yr_built', 'yr_renovated','waterfront_YES']].values
y3 = dummy2['price']
X3_constant = sm.add_constant(X3)
#X=X.reshape(-1,1)

# %%
dummy2.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'Waterfront', 'yr_renovated_missing',
#        'View', 'waterfront_NO', 'waterfront_YES'],
#       dtype='object')

# %% [markdown]
# ### Base regression model: what is the relationship between 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above' and price?

# %%
model = sm.OLS(dummy2['price'], sm.add_constant(dummy2[['sqft_above', 'bathrooms']])).fit()
#predictions = model.predict(X)  #ask about x_constant

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     5698.
# Date:                Mon, 11 Apr 2022   Prob (F-statistic):               0.00
# Time:                        19:51:44   Log-Likelihood:            -2.4758e+05
# No. Observations:               17703   AIC:                         4.952e+05
# Df Residuals:                   17700   BIC:                         4.952e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.005e+04   6386.740     -6.271      0.000   -5.26e+04   -2.75e+04
# ...

# %%
y, X = dmatrices('price ~ sqft_above+bathrooms+sqft_living+sqft_basement', data=df, return_type='dataframe')

#calculate VIF for each explanatory variable
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['variable'] = X.columns

#view VIF for each explanatory variable 
vif

# %%
df['yr_built'].max()

# %%
model1 = sm.OLS(dummy2['price'], sm.add_constant(dummy2[['sqft_above', 'bathrooms', 'sqft_lot', 'floors', 'sqft_above', 'yr_built']])).fit()
#predictions = model.predict(X)  #ask about x_constant

print_model1 = model1.summary()
print(print_model1)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     3245.
# Date:                Thu, 07 Apr 2022   Prob (F-statistic):               0.00
# Time:                        20:19:05   Log-Likelihood:            -2.4622e+05
# No. Observations:               17703   AIC:                         4.925e+05
# Df Residuals:                   17697   BIC:                         4.925e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.975e+06   1.59e+05     50.032      0.000    7.66e+06    8.29e+06
# ...

# %%
model2 = sm.OLS(dummy2['price'], sm.add_constant(dummy2[['sqft_above', 'bathrooms', 'sqft_lot', 'floors', 'sqft_above', 'yr_built']])).fit()
#predictions = model.predict(X)  #ask about x_constant

print_model2 = model2.summary()
print(print_model2)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.857
# Model:                            OLS   Adj. R-squared (uncentered):              0.857
# Method:                 Least Squares   F-statistic:                          1.183e+04
# Date:                Thu, 07 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        20:16:19   Log-Likelihood:                     -2.4492e+05
# No. Observations:               17703   AIC:                                  4.899e+05
# Df Residuals:                   17694   BIC:                                  4.899e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model2 = sm.OLS(y2, X2).fit()
predictions2 = model2.predict(X2)  #ask about x_constant

print_model2 = model2.summary()
print(print_model2)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.862
# Model:                            OLS   Adj. R-squared (uncentered):              0.862
# Method:                 Least Squares   F-statistic:                          1.010e+04
# Date:                Thu, 07 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        10:22:17   Log-Likelihood:                     -2.4537e+05
# No. Observations:               17755   AIC:                                  4.908e+05
# Df Residuals:                   17744   BIC:                                  4.908e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model3 = sm.OLS(y3, X3).fit()
predictions3 = model3.predict(X3)  #ask about x_constant

print_model3 = model3.summary()
print(print_model3)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.862
# Model:                            OLS   Adj. R-squared (uncentered):              0.862
# Method:                 Least Squares   F-statistic:                          1.111e+04
# Date:                Thu, 07 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        10:22:21   Log-Likelihood:                     -2.4537e+05
# No. Observations:               17755   AIC:                                  4.908e+05
# Df Residuals:                   17745   BIC:                                  4.908e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# %matplotlib inline
#%config InlineBackend.figure_format ='retina'
import seaborn as sns 
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
#sns.set_style('darkgrid')
#sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    '''
    Function for visually inspecting the assumption of linearity in a linear regression model.
    It plots observed vs. predicted values and residuals vs. predicted values.
    
    Args:
    * model - fitted OLS model from statsmodels
    * y - observed values
    '''
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(model, y)

# %%
import numpy as np 
import pylab 
import scipy.stats as stats

measurements = np.random.normal(loc = 20, scale = 5, size=100)   
stats.probplot(model, dist="norm", plot=pylab)
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-40704e7e055b> in <module>
#       4
#       5 measurements = np.random.normal(loc = 20, scale = 5, size=100)
# ----> 6 stats.probplot(model, dist="norm", plot=pylab)
#       7 pylab.show()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\morestats.py in probplot(x, sparams, dist, fit, plot, rvalue)
#     589             return x, x
#     590
# --> 591     osm_uniform = _calc_uniform_order_statistic_medians(len(x))
#     592     dist = _parse_dist_kw(dist, enforce_subclass=False)
#     593     if sparams is None:
#
# TypeError: len() of unsized object

# %%
plt.figure(figsize=(10,10))
plt.scatter(y, predictions, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(predictions), max(y))
p2 = min(min(predictions), min(y))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
dummy = pd.get_dummies(df, columns = ['view'])
dummy
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  condition  ... sqft_living15  sqft_lot15  \
# ...

# %%
dummy1 = pd.get_dummies(dummy, columns = ['waterfront'])
dummy1
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  condition          grade  ...  Waterfront  \
# ...

# %%
dummy2.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'Waterfront', 'yr_renovated_missing',
#        'View', 'view_AVERAGE', 'view_EXCELLENT', 'view_FAIR', 'view_GOOD',
#        'view_NONE', 'waterfront_NO', 'waterfront_YES'],
#       dtype='object')
